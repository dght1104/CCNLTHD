# %% [markdown]
# # Import Keras

# %%
import keras

# %% [markdown]
# # Keras was imported with TensorFlow backend
# # Let's check Keras version

# %%
import keras
print(keras.__version__)  # Kiểm tra phiên bản Keras
import tensorflow as tf
print(tf.__version__)  # Kiểm tra phiên bản TensorFlow
# Out:
# 2.13.1
# 2.13.0

# %% [markdown]
# # Check whether GPU can be used or not

# %%
print(keras.backend.tensorflow_backend._get_available_gpus())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(keras.backend.tensorflow_backend._get_available_gpus())
#
# AttributeError: module 'keras.backend' has no attribute 'tensorflow_backend'

# %% [markdown]
# ## One GPU has been detected!
