# %% [markdown]
# # **Bước 0: Import thư viện**

# %%
import keras
import os
import glob
import json
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import random
import shutil
from tensorflow.keras import models, layers,Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # **Bước 1: Đọc ảnh và file JSON**

# %%
# Đường dẫn thư mục dữ liệu gốc
IMAGE_DIR = "/kaggle/input/btxrd-data/BTXRD/BTXRD/images"
JSON_DIR = "/kaggle/input/btxrd-data/BTXRD/BTXRD/Annotations"

# Thư mục lưu kết quả sau khi xử lý
OUTPUT_IMAGE_DIR = "/kaggle/working/processed_images"
OUTPUT_JSON_DIR = "/kaggle/working/processed_annotations"

if not os.path.exists(OUTPUT_IMAGE_DIR):
    os.makedirs(OUTPUT_IMAGE_DIR, exist_ok=True)  # Tạo thư mục nếu chưa có
    print(f"✅ Đã tạo thư mục: {OUTPUT_IMAGE_DIR}")
else:
    print(f"✅ Thư mục đã tồn tại: {OUTPUT_IMAGE_DIR}")

if not os.path.exists(OUTPUT_JSON_DIR):
    os.makedirs(OUTPUT_JSON_DIR, exist_ok=True)  # Tạo thư mục nếu chưa có
    print(f"✅ Đã tạo thư mục: {OUTPUT_JSON_DIR}")
else:
    print(f"✅ Thư mục đã tồn tại: {OUTPUT_JSON_DIR}")
# Out:
# ✅ Thư mục đã tồn tại: /kaggle/working/processed_images
# ✅ Thư mục đã tồn tại: /kaggle/working/processed_annotations

# %% [markdown]
# # Bước 2: Tiền xử lý dữ liệu

# %% [markdown]
# Resize ảnh về kích thước cố định nhưng không méo hình.
# Padding ảnh để giữ nguyên tỷ lệ.
# Cập nhật tọa độ vùng ung thư trong JSON để không bị sai lệch.

# %%
# Kích thước ảnh mong muốn
TARGET_SIZE = (224, 294)  # (width, height)
def resize_and_pad_image(img_path, json_path=None):
    """ Resize ảnh về kích thước chuẩn và cập nhật tọa độ vùng ung thư trong JSON (nếu có). """
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    h, w = img.shape[:2]

    # Tính tỷ lệ resize để không làm méo ảnh
    scale = min(TARGET_SIZE[0] / w, TARGET_SIZE[1] / h)
    new_w, new_h = int(w * scale), int(h * scale)
    
    # Resize ảnh
    resized_img = cv2.resize(img, (new_w, new_h), interpolation=cv2.INTER_AREA)

    # Tạo ảnh nền trắng (uint8)
    final_img = np.ones((TARGET_SIZE[1], TARGET_SIZE[0]), dtype=np.uint8) * 255
    x_offset = (TARGET_SIZE[0] - new_w) // 2
    y_offset = (TARGET_SIZE[1] - new_h) // 2

    # Đưa ảnh vào trung tâm
    final_img[y_offset:y_offset + new_h, x_offset:x_offset + new_w] = resized_img

    # Cập nhật JSON nếu có
    updated_data = None
    if json_path and os.path.exists(json_path):
        with open(json_path, "r") as f:
            data = json.load(f)

        # Cập nhật tọa độ vùng tổn thương
        for shape in data["shapes"]:
            updated_points = [
                [round(point[0] * scale + x_offset), round(point[1] * scale + y_offset)]
                for point in shape["points"]
            ]
            shape["points"] = updated_points

        updated_data = data

    return final_img, updated_data

# Xử lý toàn bộ ảnh
image_paths = glob.glob(IMAGE_DIR + "/*.png") + glob.glob(IMAGE_DIR + "/*.jpg") + glob.glob(IMAGE_DIR + "/*.jpeg")

for img_path in image_paths:
    filename = os.path.basename(img_path).split('.')[0]  # Lấy tên file không có đuôi
    json_path = os.path.join(JSON_DIR, filename + ".json")  # Tìm file JSON tương ứng

    # Resize ảnh & cập nhật JSON
    processed_img, updated_annotations = resize_and_pad_image(img_path, json_path if os.path.exists(json_path) else None)

    # Lưu ảnh đã resize
    output_img_path = os.path.join(OUTPUT_IMAGE_DIR, filename + ".jpg")
    cv2.imwrite(output_img_path, processed_img)

    # Lưu JSON nếu có
    if updated_annotations:
        output_json_path = os.path.join(OUTPUT_JSON_DIR, filename + ".json")
        with open(output_json_path, "w") as f:
            json.dump(updated_annotations, f, indent=4)

print("✅ Xử lý hoàn tất. Ảnh và JSON đã được lưu tại:", OUTPUT_IMAGE_DIR, "và", OUTPUT_JSON_DIR)
# Out:
# ✅ Xử lý hoàn tất. Ảnh và JSON đã được lưu tại: /kaggle/working/processed_images và /kaggle/working/processed_annotations

# %% [markdown]
# # **Bước 3: Phân chia bộ test và train**

# %% [markdown]
# Phân chia ảnh thành 80% train và 20% test

# %%
OUTPUT_DIR = "/kaggle/working/"
# Tạo thư mục train, test, val
for folder in ["train", "test", "val"]:
    os.makedirs(os.path.join(OUTPUT_DIR, folder), exist_ok=True)

# Lấy danh sách ảnh
image_paths = glob.glob(os.path.join(OUTPUT_IMAGE_DIR, "*.jpg")) + \
              glob.glob(os.path.join(OUTPUT_IMAGE_DIR, "*.jpeg"))

# Shuffle dữ liệu để chia ngẫu nhiên
random.seed(42)
random.shuffle(image_paths)

# Chia theo tỷ lệ 70% train - 20% test - 10% validation
train_idx = int(0.7 * len(image_paths))
test_idx = int(0.9 * len(image_paths))  # Sau train, còn 30%, chia tiếp thành 20% test + 10% val

train_images = image_paths[:train_idx]
test_images = image_paths[train_idx:test_idx]
val_images = image_paths[test_idx:]

# Di chuyển ảnh vào thư mục tương ứng
for img_path in train_images:
    shutil.copy(img_path, os.path.join(OUTPUT_DIR, "train", os.path.basename(img_path)))

for img_path in test_images:
    shutil.copy(img_path, os.path.join(OUTPUT_DIR, "test", os.path.basename(img_path)))

for img_path in val_images:
    shutil.copy(img_path, os.path.join(OUTPUT_DIR, "val", os.path.basename(img_path)))

print("✅ Chia tập dữ liệu hoàn tất!")
# Out:
# ✅ Chia tập dữ liệu hoàn tất!

# %%
import os

test_path = "/kaggle/working/test" 
test_files = len(os.listdir(test_path))
print(f"📂 Số lượng file trong {test_path}: {test_files}")

benign_path = "/kaggle/working/train" 
benign_files = len(os.listdir(benign_path)) 
print(f"📂 Số lượng file trong {benign_path}: {benign_files}")

malignant_path = "/kaggle/working/val"
malignant_files = len(os.listdir(malignant_path)) 
print(f"📂 Số lượng file trong {malignant_path}: {malignant_files}")
# Out:
# 📂 Số lượng file trong /kaggle/working/test: 751
# 📂 Số lượng file trong /kaggle/working/train: 2624
# 📂 Số lượng file trong /kaggle/working/val: 375

# %%
# Thư mục train gốc
TRAIN_DIR = "/kaggle/working/train"
OUTPUT_JSON_DIR = "/kaggle/working/processed_annotations"

# Tạo thư mục benign/malignant trong train
for folder in ["benign", "malignant"]:
    os.makedirs(os.path.join(TRAIN_DIR, folder), exist_ok=True)

# Lấy danh sách ảnh trong train
train_images = glob.glob(os.path.join(TRAIN_DIR, "*.jpg")) + \
               glob.glob(os.path.join(TRAIN_DIR, "*.jpeg"))

# Phân loại ảnh
for img_path in train_images:
    filename = os.path.basename(img_path)
    json_path = os.path.join(OUTPUT_JSON_DIR, filename.replace(".jpg", ".json"))

    if os.path.exists(json_path):
        dest_folder = "malignant"  # Có JSON -> malignant
    else:
        dest_folder = "benign"  # Không có JSON -> benign

    shutil.move(img_path, os.path.join(TRAIN_DIR, dest_folder, filename))

print("✅ Phân loại ảnh trong train hoàn tất!")
# Out:
# ✅ Phân loại ảnh trong train hoàn tất!

# %%
# Thư mục train gốc
TEST_DIR = "/kaggle/working/test"
OUTPUT_JSON_DIR = "/kaggle/working/processed_annotations"

# Tạo thư mục benign/malignant trong train
for folder in ["benign", "malignant"]:
    os.makedirs(os.path.join(TEST_DIR, folder), exist_ok=True)

# Lấy danh sách ảnh trong train
train_images = glob.glob(os.path.join(TEST_DIR, "*.jpg")) + \
               glob.glob(os.path.join(TEST_DIR, "*.jpeg"))

# Phân loại ảnh
for img_path in train_images:
    filename = os.path.basename(img_path)
    json_path = os.path.join(OUTPUT_JSON_DIR, filename.replace(".jpg", ".json"))

    if os.path.exists(json_path):
        dest_folder = "malignant"  # Có JSON -> malignant
    else:
        dest_folder = "benign"  # Không có JSON -> benign

    shutil.move(img_path, os.path.join(TEST_DIR, dest_folder, filename))

print("✅ Phân loại ảnh trong train hoàn tất!")
# Out:
# ✅ Phân loại ảnh trong train hoàn tất!

# %%
for folder in ["benign", "malignant"]:
    count = len(glob.glob(os.path.join(TRAIN_DIR, folder, "*.jpg")))
    print(f"📂 Số lượng ảnh trong train/{folder}: {count}")

for folder in ["benign", "malignant"]:
    count = len(glob.glob(os.path.join(TEST_DIR, folder, "*.jpg")))
    print(f"📂 Số lượng ảnh trong TEST/{folder}: {count}")
# Out:
# 📂 Số lượng ảnh trong train/benign: 1308
# 📂 Số lượng ảnh trong train/malignant: 1314
# 📂 Số lượng ảnh trong TEST/benign: 378
# 📂 Số lượng ảnh trong TEST/malignant: 371

# %%
# !zip -r /kaggle/working/btxrd_v1.zip /kaggle/working/
# Out:
# updating: kaggle/working/ (stored 0%)
# updating: kaggle/working/processed_data.zip (stored 0%)
# updating: kaggle/working/btxrd_v2.zip (stored 0%)
# updating: kaggle/working/val/ (stored 0%)
# updating: kaggle/working/val/IMG000248.jpg (deflated 5%)
# updating: kaggle/working/val/IMG003172.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000254.jpg (deflated 8%)
# updating: kaggle/working/val/IMG000874.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001805.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002209.jpg (deflated 3%)
# updating: kaggle/working/val/IMG003114.jpg (deflated 6%)
# updating: kaggle/working/val/IMG002370.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000624.jpg (deflated 0%)
# updating: kaggle/working/val/IMG003468.jpg (deflated 4%)
# updating: kaggle/working/val/IMG001305.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002898.jpg (deflated 5%)
# updating: kaggle/working/val/IMG002312.jpg (deflated 10%)
# updating: kaggle/working/val/IMG002779.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003030.jpg (deflated 9%)
# updating: kaggle/working/val/IMG000564.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002597.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002290.jpg (deflated 12%)
# updating: kaggle/working/val/IMG000441.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001507.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002967.jpg (deflated 9%)
# updating: kaggle/working/val/IMG001587.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000750.jpg (deflated 1%)
# updating: kaggle/working/val/IMG003538.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002687.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002993.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002921.jpg (deflated 3%)
# updating: kaggle/working/val/IMG000882.jpg (deflated 5%)
# updating: kaggle/working/val/IMG001357.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000486.jpg (deflated 4%)
# updating: kaggle/working/val/IMG001110.jpg (deflated 6%)
# updating: kaggle/working/val/IMG001483.jpg (deflated 13%)
# updating: kaggle/working/val/IMG002146.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001180.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000122.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002233.jpg (deflated 6%)
# updating: kaggle/working/val/IMG002487.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000446.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003051.jpg (deflated 3%)
# updating: kaggle/working/val/IMG001036.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002122.jpg (deflated 8%)
# updating: kaggle/working/val/IMG002841.jpg (deflated 4%)
# updating: kaggle/working/val/IMG001759.jpg (deflated 8%)
# updating: kaggle/working/val/IMG003605.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000359.jpg (deflated 8%)
# updating: kaggle/working/val/IMG000771.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002913.jpg (deflated 6%)
# updating: kaggle/working/val/IMG001413.jpg (deflated 5%)
# updating: kaggle/working/val/IMG003266.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003284.jpg (deflated 11%)
# updating: kaggle/working/val/IMG000171.jpg (deflated 4%)
# updating: kaggle/working/val/IMG001070.jpg (deflated 4%)
# updating: kaggle/working/val/IMG003586.jpg (deflated 10%)
# updating: kaggle/working/val/IMG002844.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002818.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000324.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000215.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002071.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000995.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001544.jpg (deflated 9%)
# updating: kaggle/working/val/IMG001963.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001271.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002557.jpg (deflated 9%)
# updating: kaggle/working/val/IMG002182.jpg (deflated 5%)
# updating: kaggle/working/val/IMG001887.jpg (deflated 10%)
# updating: kaggle/working/val/IMG001153.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002528.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001135.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002364.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003288.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002018.jpg (deflated 11%)
# updating: kaggle/working/val/IMG001728.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000153.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001968.jpg (deflated 11%)
# updating: kaggle/working/val/IMG003168.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001488.jpg (deflated 5%)
# updating: kaggle/working/val/IMG002886.jpg (deflated 5%)
# updating: kaggle/working/val/IMG002053.jpg (deflated 4%)
# updating: kaggle/working/val/IMG003694.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002031.jpg (deflated 10%)
# updating: kaggle/working/val/IMG002324.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002671.jpg (deflated 8%)
# updating: kaggle/working/val/IMG000251.jpg (deflated 1%)
# updating: kaggle/working/val/IMG003384.jpg (deflated 1%)
# updating: kaggle/working/val/IMG003272.jpg (deflated 9%)
# updating: kaggle/working/val/IMG003473.jpg (deflated 5%)
# updating: kaggle/working/val/IMG001179.jpg (deflated 5%)
# updating: kaggle/working/val/IMG000271.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000250.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000976.jpg (deflated 5%)
# updating: kaggle/working/val/IMG003337.jpg (deflated 8%)
# updating: kaggle/working/val/IMG003578.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000787.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000773.jpg (deflated 5%)
# updating: kaggle/working/val/IMG000837.jpg (deflated 4%)
# updating: kaggle/working/val/IMG001181.jpg (deflated 6%)
# updating: kaggle/working/val/IMG003383.jpg (deflated 1%)
# updating: kaggle/working/val/IMG003242.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002466.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001096.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003400.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002536.jpg (deflated 9%)
# updating: kaggle/working/val/IMG003572.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000099.jpg (deflated 6%)
# updating: kaggle/working/val/IMG002563.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002920.jpg (deflated 10%)
# updating: kaggle/working/val/IMG000039.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002033.jpg (deflated 12%)
# updating: kaggle/working/val/IMG000588.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001842.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002148.jpg (deflated 0%)
# updating: kaggle/working/val/IMG000146.jpg (deflated 9%)
# updating: kaggle/working/val/IMG003281.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001644.jpg (deflated 3%)
# updating: kaggle/working/val/IMG003519.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000924.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002608.jpg (deflated 11%)
# updating: kaggle/working/val/IMG000179.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002184.jpg (deflated 10%)
# updating: kaggle/working/val/IMG003491.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000508.jpg (deflated 5%)
# updating: kaggle/working/val/IMG000760.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000625.jpg (deflated 3%)
# updating: kaggle/working/val/IMG001417.jpg (deflated 7%)
# updating: kaggle/working/val/IMG000617.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003622.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000224.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000720.jpg (deflated 9%)
# updating: kaggle/working/val/IMG003604.jpg (deflated 7%)
# updating: kaggle/working/val/IMG003092.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000079.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000805.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001955.jpg (deflated 13%)
# updating: kaggle/working/val/IMG001115.jpg (deflated 15%)
# updating: kaggle/working/val/IMG002173.jpg (deflated 10%)
# updating: kaggle/working/val/IMG000370.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002103.jpg (deflated 11%)
# updating: kaggle/working/val/IMG001095.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000688.jpg (deflated 6%)
# updating: kaggle/working/val/IMG000237.jpg (deflated 12%)
# updating: kaggle/working/val/IMG002610.jpg (deflated 9%)
# updating: kaggle/working/val/IMG001048.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000194.jpg (deflated 3%)
# updating: kaggle/working/val/IMG001346.jpg (deflated 6%)
# updating: kaggle/working/val/IMG001365.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001542.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002165.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003010.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001218.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000432.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000327.jpg (deflated 3%)
# updating: kaggle/working/val/IMG000983.jpg (deflated 11%)
# updating: kaggle/working/val/IMG001670.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003012.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003354.jpg (deflated 1%)
# updating: kaggle/working/val/IMG003283.jpg (deflated 6%)
# updating: kaggle/working/val/IMG000789.jpg (deflated 3%)
# updating: kaggle/working/val/IMG001159.jpg (deflated 3%)
# updating: kaggle/working/val/IMG003298.jpg (deflated 4%)
# updating: kaggle/working/val/IMG003244.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002827.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002580.jpg (deflated 3%)
# updating: kaggle/working/val/IMG001197.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002670.jpg (deflated 10%)
# updating: kaggle/working/val/IMG000894.jpg (deflated 3%)
# updating: kaggle/working/val/IMG003249.jpg (deflated 4%)
# updating: kaggle/working/val/IMG003685.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002917.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000792.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002142.jpg (deflated 7%)
# updating: kaggle/working/val/IMG003146.jpg (deflated 4%)
# updating: kaggle/working/val/IMG001967.jpg (deflated 6%)
# updating: kaggle/working/val/IMG001747.jpg (deflated 5%)
# updating: kaggle/working/val/IMG001874.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002626.jpg (deflated 5%)
# updating: kaggle/working/val/IMG000007.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002002.jpg (deflated 6%)
# updating: kaggle/working/val/IMG002764.jpg (deflated 10%)
# updating: kaggle/working/val/IMG000334.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000676.jpg (deflated 11%)
# updating: kaggle/working/val/IMG002288.jpg (deflated 14%)
# updating: kaggle/working/val/IMG002123.jpg (deflated 5%)
# updating: kaggle/working/val/IMG002958.jpg (deflated 6%)
# updating: kaggle/working/val/IMG001154.jpg (deflated 0%)
# updating: kaggle/working/val/IMG000355.jpg (deflated 4%)
# updating: kaggle/working/val/IMG001041.jpg (deflated 3%)
# updating: kaggle/working/val/IMG003167.jpg (deflated 8%)
# updating: kaggle/working/val/IMG000301.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000183.jpg (deflated 10%)
# updating: kaggle/working/val/IMG000704.jpg (deflated 3%)
# updating: kaggle/working/val/IMG000278.jpg (deflated 10%)
# updating: kaggle/working/val/IMG000521.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001392.jpg (deflated 9%)
# updating: kaggle/working/val/IMG001089.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000509.jpg (deflated 3%)
# updating: kaggle/working/val/IMG001803.jpg (deflated 3%)
# updating: kaggle/working/val/IMG001956.jpg (deflated 20%)
# updating: kaggle/working/val/IMG003003.jpg (deflated 8%)
# updating: kaggle/working/val/IMG002272.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002138.jpg (deflated 9%)
# updating: kaggle/working/val/IMG002721.jpg (deflated 7%)
# updating: kaggle/working/val/IMG001896.jpg (deflated 6%)
# updating: kaggle/working/val/IMG002105.jpg (deflated 10%)
# updating: kaggle/working/val/IMG002315.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002481.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002393.jpg (deflated 3%)
# updating: kaggle/working/val/IMG000974.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003227.jpg (deflated 13%)
# updating: kaggle/working/val/IMG000513.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001660.jpg (deflated 4%)
# updating: kaggle/working/val/IMG001725.jpg (deflated 5%)
# updating: kaggle/working/val/IMG001516.jpg (deflated 5%)
# updating: kaggle/working/val/IMG003036.jpg (deflated 10%)
# updating: kaggle/working/val/IMG000398.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002465.jpg (deflated 11%)
# updating: kaggle/working/val/IMG003013.jpg (deflated 8%)
# updating: kaggle/working/val/IMG000368.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002291.jpg (deflated 10%)
# updating: kaggle/working/val/IMG000714.jpg (deflated 23%)
# updating: kaggle/working/val/IMG001034.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002101.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002771.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000951.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000913.jpg (deflated 3%)
# updating: kaggle/working/val/IMG003378.jpg (deflated 3%)
# updating: kaggle/working/val/IMG000677.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002932.jpg (deflated 9%)
# updating: kaggle/working/val/IMG000404.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001969.jpg (deflated 12%)
# updating: kaggle/working/val/IMG001972.jpg (deflated 7%)
# updating: kaggle/working/val/IMG002633.jpg (deflated 10%)
# updating: kaggle/working/val/IMG000333.jpg (deflated 0%)
# updating: kaggle/working/val/IMG000102.jpg (deflated 11%)
# updating: kaggle/working/val/IMG001679.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001838.jpg (deflated 5%)
# updating: kaggle/working/val/IMG002443.jpg (deflated 9%)
# updating: kaggle/working/val/IMG001487.jpg (deflated 12%)
# updating: kaggle/working/val/IMG003626.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002263.jpg (deflated 3%)
# updating: kaggle/working/val/IMG000551.jpg (deflated 18%)
# updating: kaggle/working/val/IMG000801.jpg (deflated 6%)
# updating: kaggle/working/val/IMG002319.jpg (deflated 17%)
# updating: kaggle/working/val/IMG000727.jpg (deflated 1%)
# updating: kaggle/working/val/IMG003508.jpg (deflated 5%)
# updating: kaggle/working/val/IMG000833.jpg (deflated 0%)
# updating: kaggle/working/val/IMG000409.jpg (deflated 6%)
# updating: kaggle/working/val/IMG000187.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001991.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002267.jpg (deflated 10%)
# updating: kaggle/working/val/IMG003137.jpg (deflated 4%)
# updating: kaggle/working/val/IMG003023.jpg (deflated 8%)
# updating: kaggle/working/val/IMG003385.jpg (deflated 7%)
# updating: kaggle/working/val/IMG001539.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002378.jpg (deflated 13%)
# updating: kaggle/working/val/IMG000630.jpg (deflated 10%)
# updating: kaggle/working/val/IMG002757.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002820.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000387.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000829.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002946.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001575.jpg (deflated 3%)
# updating: kaggle/working/val/IMG001470.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000156.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000519.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002533.jpg (deflated 5%)
# updating: kaggle/working/val/IMG003352.jpg (deflated 3%)
# updating: kaggle/working/val/IMG000613.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002688.jpg (deflated 12%)
# updating: kaggle/working/val/IMG000473.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002048.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002230.jpg (deflated 11%)
# updating: kaggle/working/val/IMG001684.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000992.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001954.jpg (deflated 12%)
# updating: kaggle/working/val/IMG001025.jpg (deflated 13%)
# updating: kaggle/working/val/IMG002628.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000798.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002172.jpg (deflated 20%)
# updating: kaggle/working/val/IMG000363.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001137.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002904.jpg (deflated 8%)
# updating: kaggle/working/val/IMG003076.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002643.jpg (deflated 8%)
# updating: kaggle/working/val/IMG000070.jpg (deflated 10%)
# updating: kaggle/working/val/IMG001490.jpg (deflated 6%)
# updating: kaggle/working/val/IMG002803.jpg (deflated 0%)
# updating: kaggle/working/val/IMG000129.jpg (deflated 1%)
# updating: kaggle/working/val/IMG003101.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001404.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002161.jpg (deflated 9%)
# updating: kaggle/working/val/IMG002241.jpg (deflated 6%)
# updating: kaggle/working/val/IMG002740.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002444.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000759.jpg (deflated 22%)
# updating: kaggle/working/val/IMG002860.jpg (deflated 6%)
# updating: kaggle/working/val/IMG002525.jpg (deflated 11%)
# updating: kaggle/working/val/IMG001203.jpg (deflated 6%)
# updating: kaggle/working/val/IMG001233.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000298.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001331.jpg (deflated 8%)
# updating: kaggle/working/val/IMG000220.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001992.jpg (deflated 4%)
# updating: kaggle/working/val/IMG003152.jpg (deflated 9%)
# updating: kaggle/working/val/IMG003291.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002478.jpg (deflated 7%)
# updating: kaggle/working/val/IMG002185.jpg (deflated 10%)
# updating: kaggle/working/val/IMG001160.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002489.jpg (deflated 10%)
# updating: kaggle/working/val/IMG002192.jpg (deflated 15%)
# updating: kaggle/working/val/IMG001665.jpg (deflated 1%)
# updating: kaggle/working/val/IMG000392.jpg (deflated 4%)
# updating: kaggle/working/val/IMG001090.jpg (deflated 3%)
# updating: kaggle/working/val/IMG000350.jpg (deflated 7%)
# updating: kaggle/working/val/IMG002133.jpg (deflated 0%)
# updating: kaggle/working/val/IMG001230.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003194.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000890.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001571.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000971.jpg (deflated 9%)
# updating: kaggle/working/val/IMG003534.jpg (deflated 9%)
# updating: kaggle/working/val/IMG002815.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002389.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000208.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003575.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002203.jpg (deflated 8%)
# updating: kaggle/working/val/IMG003125.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000048.jpg (deflated 6%)
# updating: kaggle/working/val/IMG001086.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002089.jpg (deflated 12%)
# updating: kaggle/working/val/IMG001825.jpg (deflated 3%)
# updating: kaggle/working/val/IMG000173.jpg (deflated 10%)
# updating: kaggle/working/val/IMG000761.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002406.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001890.jpg (deflated 14%)
# updating: kaggle/working/val/IMG003381.jpg (deflated 2%)
# updating: kaggle/working/val/IMG001659.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002824.jpg (deflated 3%)
# updating: kaggle/working/val/IMG002928.jpg (deflated 11%)
# updating: kaggle/working/val/IMG001513.jpg (deflated 6%)
# updating: kaggle/working/val/IMG000066.jpg (deflated 6%)
# updating: kaggle/working/val/IMG000495.jpg (deflated 16%)
# updating: kaggle/working/val/IMG003489.jpg (deflated 4%)
# updating: kaggle/working/val/IMG001817.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002316.jpg (deflated 19%)
# updating: kaggle/working/val/IMG002026.jpg (deflated 0%)
# updating: kaggle/working/val/IMG003147.jpg (deflated 7%)
# updating: kaggle/working/val/IMG003163.jpg (deflated 5%)
# updating: kaggle/working/val/IMG001594.jpg (deflated 1%)
# updating: kaggle/working/val/IMG002982.jpg (deflated 9%)
# updating: kaggle/working/val/IMG000689.jpg (deflated 1%)
# updating: kaggle/working/val/IMG003529.jpg (deflated 4%)
# updating: kaggle/working/val/IMG000106.jpg (deflated 10%)
# updating: kaggle/working/val/IMG001994.jpg (deflated 8%)
# updating: kaggle/working/val/IMG000012.jpg (deflated 0%)
# updating: kaggle/working/val/IMG003046.jpg (deflated 8%)
# updating: kaggle/working/val/IMG001898.jpg (deflated 5%)
# updating: kaggle/working/val/IMG002950.jpg (deflated 7%)
# updating: kaggle/working/val/IMG000142.jpg (deflated 3%)
# updating: kaggle/working/val/IMG000292.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002252.jpg (deflated 11%)
# updating: kaggle/working/val/IMG002399.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002245.jpg (deflated 12%)
# updating: kaggle/working/val/IMG001736.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003501.jpg (deflated 11%)
# updating: kaggle/working/val/IMG001506.jpg (deflated 2%)
# updating: kaggle/working/val/IMG003639.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002348.jpg (deflated 2%)
# updating: kaggle/working/val/IMG000822.jpg (deflated 4%)
# updating: kaggle/working/val/IMG002543.jpg (deflated 8%)
# updating: kaggle/working/val/IMG001054.jpg (deflated 10%)
# updating: kaggle/working/val/IMG002837.jpg (deflated 2%)
# updating: kaggle/working/val/IMG002909.jpg (deflated 5%)
# updating: kaggle/working/val/IMG001362.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001373.jpg (deflated 1%)
# updating: kaggle/working/val/IMG001257.jpg (deflated 9%)
# updating: kaggle/working/train/ (stored 0%)
# updating: kaggle/working/train/malignant/ (stored 0%)
# updating: kaggle/working/train/malignant/IMG000244.jpg (deflated 11%)
# updating: kaggle/working/train/malignant/IMG001462.jpg (deflated 14%)
# updating: kaggle/working/train/malignant/IMG001069.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001288.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000926.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000786.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000892.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000400.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001367.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001755.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG001737.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001175.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG001336.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000754.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG000063.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000518.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001301.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001631.jpg (deflated 14%)
# updating: kaggle/working/train/malignant/IMG001435.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG001158.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001867.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG000993.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000493.jpg (deflated 22%)
# updating: kaggle/working/train/malignant/IMG001087.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001843.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000181.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001734.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG001285.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001277.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000621.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001559.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG000600.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000661.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001037.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000083.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG001634.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001623.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000345.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000847.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001019.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000889.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG001533.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000956.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000131.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001774.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000891.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001595.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG001766.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG000382.jpg (deflated 14%)
# updating: kaggle/working/train/malignant/IMG001773.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG000618.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000136.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG001201.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001582.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000202.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001527.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG001010.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG001176.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000243.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000152.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000161.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000117.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001495.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG001690.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000075.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001624.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG000423.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001745.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001122.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG000819.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG001098.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000548.jpg (deflated 12%)
# updating: kaggle/working/train/malignant/IMG000406.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000291.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG000814.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG000674.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000896.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000531.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001452.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG000430.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001322.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001504.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000203.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000293.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000469.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG001672.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG000435.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000699.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG001427.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000200.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001605.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000964.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000738.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000396.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000393.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000512.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000029.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG000408.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001318.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001853.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000297.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001150.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG001207.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG000823.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG000056.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000209.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000107.jpg (deflated 11%)
# updating: kaggle/working/train/malignant/IMG000932.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000986.jpg (deflated 14%)
# updating: kaggle/working/train/malignant/IMG000560.jpg (deflated 20%)
# updating: kaggle/working/train/malignant/IMG000290.jpg (deflated 14%)
# updating: kaggle/working/train/malignant/IMG000855.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000465.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001425.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000481.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001473.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000246.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG001251.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000103.jpg (deflated 13%)
# updating: kaggle/working/train/malignant/IMG000419.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001131.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000637.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000030.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000747.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000074.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG001664.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000471.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001402.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG001017.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001752.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG001830.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001821.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001524.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000996.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001408.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000032.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001406.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000884.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000438.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG001352.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001205.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001364.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000111.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001826.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000780.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000127.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000472.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG000690.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000850.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001639.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000414.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001215.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG001494.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG001410.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG001222.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001481.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000616.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001837.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000726.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG001806.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000915.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001731.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000572.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG001332.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG000839.jpg (deflated 12%)
# updating: kaggle/working/train/malignant/IMG001335.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001079.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000073.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG001330.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000736.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000289.jpg (deflated 14%)
# updating: kaggle/working/train/malignant/IMG001360.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000779.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001468.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001777.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000028.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG001851.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000707.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG000933.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG001718.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000395.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001372.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000540.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG001183.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000685.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001560.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000452.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG000662.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000977.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000198.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001520.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG001612.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001253.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000619.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001476.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG000109.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001381.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000331.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000880.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001094.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001428.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000597.jpg (deflated 11%)
# updating: kaggle/working/train/malignant/IMG000563.jpg (deflated 25%)
# updating: kaggle/working/train/malignant/IMG001802.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000748.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG000108.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001044.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG001671.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000978.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000095.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000591.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001650.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000365.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG001829.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001188.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000808.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000321.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000752.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG001485.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG000034.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000436.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000001.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001501.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001393.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000019.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000846.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000544.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG001067.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000708.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG001146.jpg (deflated 12%)
# updating: kaggle/working/train/malignant/IMG001267.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001117.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000082.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000552.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000817.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001547.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG000177.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000642.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001783.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG000565.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000315.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000782.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001779.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001730.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001809.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001426.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG001366.jpg (deflated 11%)
# updating: kaggle/working/train/malignant/IMG001841.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001765.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001099.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000348.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000611.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001065.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG001567.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001298.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG001712.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001438.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001327.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000842.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000537.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000175.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG001439.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000982.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG001489.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG001066.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG001126.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000898.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000283.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG001586.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001142.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001770.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001863.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000354.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001599.jpg (deflated 13%)
# updating: kaggle/working/train/malignant/IMG001229.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000399.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001554.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000958.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000532.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000609.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001344.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001687.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001532.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG001170.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG000449.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000734.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001785.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG000843.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001857.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000831.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001598.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001047.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000113.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001035.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000550.jpg (deflated 19%)
# updating: kaggle/working/train/malignant/IMG000777.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG001768.jpg (deflated 12%)
# updating: kaggle/working/train/malignant/IMG000717.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000594.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000463.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000184.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG000929.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001852.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000582.jpg (deflated 14%)
# updating: kaggle/working/train/malignant/IMG000182.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000549.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG000475.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000724.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001649.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001767.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000035.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000421.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG000015.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001003.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000701.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001698.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG001312.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000090.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000326.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001339.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000650.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000751.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG001557.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG000578.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000973.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000923.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001689.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001148.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG001208.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG001475.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG001206.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000159.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG000795.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000384.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001683.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001024.jpg (deflated 11%)
# updating: kaggle/working/train/malignant/IMG001742.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000857.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000199.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG001791.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG001854.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000815.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG000149.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG001168.jpg (deflated 9%)
# updating: kaggle/working/train/malignant/IMG000158.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000970.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG000466.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001045.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000003.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG001630.jpg (deflated 13%)
# updating: kaggle/working/train/malignant/IMG000038.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001810.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000820.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG000123.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG001457.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG001026.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001692.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG001505.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000524.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001713.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000769.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000907.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG000351.jpg (deflated 10%)
# updating: kaggle/working/train/malignant/IMG001645.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000725.jpg (deflated 1%)
# updating: kaggle/working/train/malignant/IMG000371.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000877.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG001799.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001597.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG000150.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000241.jpg (deflated 2%)
# updating: kaggle/working/train/malignant/IMG000229.jpg (deflated 4%)
# updating: kaggle/working/train/malignant/IMG001472.jpg (deflated 5%)
# updating: kaggle/working/train/malignant/IMG001715.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG001482.jpg (deflated 8%)
# updating: kaggle/working/train/malignant/IMG000310.jpg (deflated 0%)
# updating: kaggle/working/train/malignant/IMG000232.jpg (deflated 3%)
# updating: kaggle/working/train/malignant/IMG001446.jpg (deflated 7%)
# updating: kaggle/working/train/malignant/IMG001445.jpg (deflated 6%)
# updating: kaggle/working/train/malignant/IMG000378.jpg (deflated 4%)
# ...
# updating: kaggle/working/processed_images/IMG001225.jpg (deflated 19%)
# updating: kaggle/working/processed_images/IMG000858.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG002021.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG000516.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG003466.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG000583.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG000106.jpg (deflated 10%)
# updating: kaggle/working/processed_images/IMG001317.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG001994.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG001989.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000012.jpg (deflated 0%)
# updating: kaggle/working/processed_images/IMG003702.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG000788.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG000944.jpg (deflated 11%)
# updating: kaggle/working/processed_images/IMG002874.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000579.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG001340.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000147.jpg (deflated 9%)
# updating: kaggle/working/processed_images/IMG002473.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG001814.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG003046.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG001102.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG001914.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG001655.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG001569.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG003107.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG003530.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG002210.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG001478.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG001864.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG001898.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG003306.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG002550.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG003090.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG002795.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000848.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG002207.jpg (deflated 9%)
# updating: kaggle/working/processed_images/IMG002710.jpg (deflated 18%)
# updating: kaggle/working/processed_images/IMG003696.jpg (deflated 0%)
# updating: kaggle/working/processed_images/IMG000768.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG001136.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG002950.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG000168.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG001343.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000416.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG003397.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG002968.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG002484.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG002629.jpg (deflated 10%)
# updating: kaggle/working/processed_images/IMG000426.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG003429.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001531.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001858.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG002419.jpg (deflated 11%)
# updating: kaggle/working/processed_images/IMG000098.jpg (deflated 0%)
# updating: kaggle/working/processed_images/IMG001562.jpg (deflated 12%)
# updating: kaggle/working/processed_images/IMG003500.jpg (deflated 9%)
# updating: kaggle/working/processed_images/IMG001588.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG001872.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG000142.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000570.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG000762.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG002302.jpg (deflated 12%)
# updating: kaggle/working/processed_images/IMG002366.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG001359.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000632.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG003545.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG000389.jpg (deflated 14%)
# updating: kaggle/working/processed_images/IMG000672.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG000912.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG000292.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG001405.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG002695.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001900.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG001580.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG003043.jpg (deflated 9%)
# updating: kaggle/working/processed_images/IMG000071.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG000651.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG003034.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG001268.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG000358.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG000959.jpg (deflated 9%)
# updating: kaggle/working/processed_images/IMG000722.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG000218.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG000511.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG001493.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG000379.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG000492.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG001703.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000385.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG003330.jpg (deflated 9%)
# updating: kaggle/working/processed_images/IMG000922.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG002252.jpg (deflated 11%)
# updating: kaggle/working/processed_images/IMG002532.jpg (deflated 12%)
# updating: kaggle/working/processed_images/IMG002300.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG001198.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG000966.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000706.jpg (deflated 11%)
# updating: kaggle/working/processed_images/IMG000900.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG000943.jpg (deflated 9%)
# updating: kaggle/working/processed_images/IMG003716.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001459.jpg (deflated 12%)
# updating: kaggle/working/processed_images/IMG001211.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG002805.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG000791.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG002399.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG001325.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG002245.jpg (deflated 12%)
# updating: kaggle/working/processed_images/IMG002351.jpg (deflated 13%)
# updating: kaggle/working/processed_images/IMG001223.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG000530.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG003214.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001847.jpg (deflated 0%)
# updating: kaggle/working/processed_images/IMG003479.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001085.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG002356.jpg (deflated 10%)
# updating: kaggle/working/processed_images/IMG000085.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001736.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG001781.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG003526.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG003676.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001545.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG003049.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG000242.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG002094.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG000118.jpg (deflated 10%)
# updating: kaggle/working/processed_images/IMG002769.jpg (deflated 0%)
# updating: kaggle/working/processed_images/IMG003398.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG002010.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG002051.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG002355.jpg (deflated 9%)
# updating: kaggle/working/processed_images/IMG000634.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG001846.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000383.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG000852.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG003501.jpg (deflated 11%)
# updating: kaggle/working/processed_images/IMG001607.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG003594.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG003375.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG001200.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG002882.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG003006.jpg (deflated 10%)
# updating: kaggle/working/processed_images/IMG000669.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG003484.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG002825.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG000553.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG002085.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG002135.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG002278.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG000077.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG000137.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG000797.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG002806.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001084.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG000502.jpg (deflated 18%)
# updating: kaggle/working/processed_images/IMG000190.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG002353.jpg (deflated 12%)
# updating: kaggle/working/processed_images/IMG003430.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG000364.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG001705.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG001506.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG003274.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG002705.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG003639.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG003670.jpg (deflated 10%)
# updating: kaggle/working/processed_images/IMG001380.jpg (deflated 10%)
# updating: kaggle/working/processed_images/IMG002073.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG001700.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG002798.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG000261.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001552.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG003141.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG003490.jpg (deflated 0%)
# updating: kaggle/working/processed_images/IMG000763.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG002348.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG003730.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG003371.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG002075.jpg (deflated 13%)
# updating: kaggle/working/processed_images/IMG002972.jpg (deflated 10%)
# updating: kaggle/working/processed_images/IMG001609.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG002700.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG000822.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG002543.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG003402.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG003145.jpg (deflated 12%)
# updating: kaggle/working/processed_images/IMG002024.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG001899.jpg (deflated 11%)
# updating: kaggle/working/processed_images/IMG001108.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG002377.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG000686.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG002796.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG000840.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG003071.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG000794.jpg (deflated 0%)
# updating: kaggle/working/processed_images/IMG001054.jpg (deflated 10%)
# updating: kaggle/working/processed_images/IMG003723.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG002107.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG002884.jpg (deflated 11%)
# updating: kaggle/working/processed_images/IMG002837.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG002460.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG002909.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG000274.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG003392.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG000207.jpg (deflated 6%)
# updating: kaggle/working/processed_images/IMG002842.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG003346.jpg (deflated 10%)
# updating: kaggle/working/processed_images/IMG001348.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001191.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG000484.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001235.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG001362.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG001561.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG003539.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG003394.jpg (deflated 8%)
# updating: kaggle/working/processed_images/IMG003440.jpg (deflated 7%)
# updating: kaggle/working/processed_images/IMG000836.jpg (deflated 3%)
# updating: kaggle/working/processed_images/IMG003740.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG001556.jpg (deflated 0%)
# updating: kaggle/working/processed_images/IMG002915.jpg (deflated 11%)
# updating: kaggle/working/processed_images/IMG001373.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG002814.jpg (deflated 9%)
# updating: kaggle/working/processed_images/IMG001750.jpg (deflated 1%)
# updating: kaggle/working/processed_images/IMG000031.jpg (deflated 2%)
# updating: kaggle/working/processed_images/IMG000067.jpg (deflated 4%)
# updating: kaggle/working/processed_images/IMG002295.jpg (deflated 5%)
# updating: kaggle/working/processed_images/IMG001257.jpg (deflated 9%)
# updating: kaggle/working/processed_images/IMG003418.jpg (deflated 5%)
# updating: kaggle/working/.virtual_documents/ (stored 0%)

# %%
cp /kaggle/working/btxrd_v1.zip /kaggle/input/
# Out:
# cp: cannot create regular file '/kaggle/input/btxrd_v1.zip': Read-only file system

# %% [markdown]
# # **Bước 4: Xây dựng hệ thống CNN**

# %%
# Định nghĩa ImageDataGenerator cho train + validation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # 🔥 Chia 20% từ train làm validation
)

test_datagen = ImageDataGenerator(rescale=1./255)  # Chỉ cần chuẩn hóa cho test

# Load ảnh từ thư mục train (chia train/val tự động)
train_generator = train_datagen.flow_from_directory(
    "/kaggle/working/train",  
    target_size=(224, 294),
    batch_size=32,
    class_mode="categorical",
    subset="training"  # 🔥 Chỉ lấy phần training (80%)
)

val_generator = train_datagen.flow_from_directory(
    "/kaggle/working/train",
    target_size=(224, 294),
    batch_size=32,
    class_mode="categorical",
    subset="validation"  # 🔥 Chỉ lấy phần validation (20%)
)

# Load ảnh từ thư mục test
test_generator = test_datagen.flow_from_directory(
    "/kaggle/working/test",
    target_size=(224, 294),
    batch_size=32,
    class_mode="categorical",
    shuffle=False  # Không shuffle để đảm bảo đánh giá đúng
)

print("✅ Load dữ liệu hoàn tất!")
# Out:
# Found 2099 images belonging to 2 classes.
# Found 523 images belonging to 2 classes.
# Found 749 images belonging to 2 classes.
# ✅ Load dữ liệu hoàn tất!

# %%
model = models.Sequential([
    Input(shape=(224, 294, 3)),  
    layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    layers.Conv2D(32, (3,3), activation='relu', padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    layers.Conv2D(128, (3,3), activation='relu', padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Conv2D(256, (3,3), activation='relu', padding='same'),
    layers.Conv2D(256, (3,3), activation='relu', padding='same'),
    layers.MaxPooling2D((2,2)),
    layers.Dropout(0.25),

    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(2, activation='softmax')  # Sửa lại số lớp đầu ra
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_16 (Conv2D)                   │ (None, 224, 294, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_17 (Conv2D)                   │ (None, 224, 294, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 112, 147, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 112, 147, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 112, 147, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 112, 147, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 56, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 56, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_20 (Conv2D)                   │ (None, 56, 73, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 56, 73, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 28, 36, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 28, 36, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 28, 36, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 28, 36, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 14, 18, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 14, 18, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 64512)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 512)                 │      33,030,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 2)                   │           1,026 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 34,203,938 (130.48 MB)
#  Trainable params: 34,203,938 (130.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # **Huấn luyện mô hình**

# %%
# model.fit(train_generator,
#           epochs=20,
#           validation_data=val_generator)

# %%
# model.save('/kaggle/working/model.h5')  # Lưu mô hình
# print("Mô hình đã được lưu thành công!")

# %%
# from IPython.display import FileLink

# FileLink("/kaggle/working/model.h5")  # Hiển thị link tải file
